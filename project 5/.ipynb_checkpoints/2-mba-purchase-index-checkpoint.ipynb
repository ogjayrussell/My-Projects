# %%
# MBA purchase index is the Mortgage Bankers Association's weekly measurement of nationwide home loan applications based on a sample of about 75% of US mortgage activity.
import pandas as pd
from utils import eda_charts

# %%
df = pd.read_csv('./data/mba_purchase_index_wk.csv')
df.head()
# Out:
#         index  purchase_index
# 0  2014-09-17           169.3
# 1  2014-09-24           168.8
# 2  2014-10-01           168.8
# 3  2014-10-08           172.9
# 4  2014-10-15           171.7

# %%
df.set_index('index', inplace=True)

# %%
df
# Out:
#             purchase_index
# index
# 2014-09-17           169.3
# 2014-09-24           168.8
# 2014-10-01           168.8
# 2014-10-08           172.9
# 2014-10-15           171.7
# ...                    ...
# 2022-05-25           225.5
# 2022-06-01           224.1
# 2022-06-08           208.2
# 2022-06-15           225.0
# 2022-06-22           242.8
#
# [398 rows x 1 columns]

# %% [markdown]
# **Findings:** It seems that there's a normal distribution with the purchase index. Outliers are also evident but have decided to keep them. There was a steep decline in the PI as COVID had hit and the residuals in the seasonal_decomp emphasises this notion. The autocorrelation plot reveals that there's a trend, and a very minor indication of seasonality with the slight scallop shape. Partial correlation doesn't fully confirm seasonality although we can see that a significan positive autocorrelation is followed by a negative value.

# %%
eda_charts(df, period = 30, lags = 20)
# Out:
#                 count        mean        std    min    25%     50%      75%  \
# purchase_index  398.0  245.183417  37.853189  155.2  224.0  243.05  267.325
#
#                   max
# purchase_index  348.2
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 398 entries, 2014-09-17 to 2022-06-22
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   purchase_index  398 non-null    float64
# dtypes: float64(1)
# memory usage: 6.2 KB
# None
