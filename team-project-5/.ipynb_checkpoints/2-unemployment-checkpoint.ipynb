# %%
import pandas as pd
import utils

# %%
df = pd.read_csv('./data/unemployment_cleaned.csv')
df.head()
# Out:
#         month  alabama  alaska  arizona  arkansas  california  colorado  \
# 0  2012-05-01    0.084   0.073    0.085     0.073       0.108     0.082
# 1  2012-06-01    0.083   0.073    0.084     0.073       0.107     0.082
# 2  2012-07-01    0.082   0.072    0.083     0.073       0.105     0.081
# 3  2012-08-01    0.081   0.072    0.082     0.072       0.103     0.079
# 4  2012-09-01    0.079   0.071    0.081     0.072       0.102     0.078
#
#    connecticut  delaware  district of columbia  ...  south dakota  tennessee  \
# 0        0.084     0.071                 0.091  ...         0.041      0.080
# 1        0.084     0.071                 0.090  ...         0.041      0.080
# 2        0.084     0.071                 0.088  ...         0.041      0.080
# 3        0.084     0.071                 0.087  ...         0.041      0.079
# 4        0.084     0.071                 0.086  ...         0.040      0.078
#
# ...

# %%
df.set_index('month', inplace=True)

# %% [markdown]
# **Findings** All outliers indicated by the box plots can be attributed towards the impact of covid seen on the line plot. North Dakota and Hawaii have an unusually high amount of outliers, meaning that their work force faced a larger impact, maybe suggesting that housing affordability may be hindered.

# %%
utils.line_plot(df, 'Unemployment', xlabels='Year', ylabels='Unemployment Percentage (State)')

# %%
utils.sub_box_plot(df, 'Unemployment')

# %%
utils.eda_charts(df[['california','new york','florida']])
# Out:
#             count      mean       std    min    25%    50%    75%    max
# california  121.0  0.067537  0.025493  0.040  0.046  0.058  0.084  0.161
# new york    121.0  0.060851  0.023804  0.037  0.046  0.052  0.075  0.165
# florida     121.0  0.055025  0.021637  0.027  0.038  0.049  0.067  0.139
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 121 entries, 2012-05-01 to 2022-05-01
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   california  121 non-null    float64
#  1   new york    121 non-null    float64
#  2   florida     121 non-null    float64
# dtypes: float64(3)
# memory usage: 3.8 KB
# None
# ...
