# %%
import pandas as pd
import utils

# %%
df = pd.read_csv('./data/deprecated/debt_service.csv')
df.head()
# Out:
#         index  total_debt  mortgage_debt  consumer_debt
# 0  1980-01-01   10.615740       4.375714       6.240027
# 1  1980-04-01   10.636900       4.484928       6.151972
# 2  1980-07-01   10.406386       4.493386       5.913000
# 3  1980-10-01   10.252837       4.512131       5.740706
# 4  1981-01-01   10.287516       4.596082       5.691433

# %%
df.set_index('index', inplace=True)
df.index = pd.to_datetime(df.index)

# %% [markdown]
# **Findings:** There is an expected drop in debt after the GFC in 2008. This is evident in the line plot for mortgage debt which is also reflected in total debt. The Autocorrelation plot also reveals that there is trend and the partial autocorrelation plot confirms no seaasonality since all after the first 2 lags are insignificant. Consumer debt seems to have a lot steeper decline in debt around 1993 compared to mortgage debt.

# %%
utils.eda_charts(df)
# Out:
#                count       mean       std       min        25%        50%  \
# total_debt     169.0  11.084612  1.036254  8.384155  10.287516  11.166536
# mortgage_debt  169.0   5.415265  0.820499  3.505480   4.850575   5.594200
# consumer_debt  169.0   5.669346  0.472634  4.648903   5.394652   5.673696
#
#                      75%        max
# total_debt     11.827220  13.172721
# mortgage_debt   5.837651   7.183105
# consumer_debt   5.972178   6.733122
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 169 entries, 1980-01-01 to 2022-01-01
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   total_debt     169 non-null    float64
#  1   mortgage_debt  169 non-null    float64
#  2   consumer_debt  169 non-null    float64
# dtypes: float64(3)
# memory usage: 5.3 KB
# None
# ...
